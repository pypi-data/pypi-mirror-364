# %%
import pandas as pd

# %%
df = pd.read_excel(r'D:\Projects\whakaari\output\_extract_features\hf_2025-01-03.xlsx', engine='openpyxl')

# %%
df.head(5)
# Out:
#                  time  hf__abs_energy  hf__absolute_sum_of_changes  \
# 0 2025-01-03 00:00:00    2.485689e+23                 1.692119e+12
# 1 2025-01-03 12:00:00    2.915903e+23                 2.186901e+12
# 2 2025-01-04 00:00:00    2.634886e+23                 2.421340e+12
# 3 2025-01-04 12:00:00    3.093626e+23                 2.821545e+12
# 4 2025-01-05 00:00:00    3.146756e+23                 2.793854e+12
#
#    hf__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                          0.120912
# 1                                          0.130662
# 2                                          0.181522
# 3                                          0.213474
# 4                                          0.212636
#
#    hf__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                           0.077056
# 1                                           0.129496
# 2                                           0.189672
# ...
