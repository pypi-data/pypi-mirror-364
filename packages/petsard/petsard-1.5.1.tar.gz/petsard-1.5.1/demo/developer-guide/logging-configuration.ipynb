# %% [markdown]
# # Environment setting
# 環境設定

# %%
import os
import requests
import sys
from pathlib import Path
from pprint import pprint
from typing import Optional

import pandas as pd


# determine branch, default is main
branch: str = "main"

# determine subfolder, default is None (petsard/demo/)
subfolder: Optional[str] = "developer-guide"


# Check if running in Google Colab, if so, download the utils.py file from GitHub
is_colab: bool = "COLAB_GPU" in os.environ
if is_colab:
    utils_url = (
        f"https://raw.githubusercontent.com/nics-tw/petsard/{branch}/demo/utils.py"
    )
    response = requests.get(utils_url)

    if response.status_code == 200:
        with open("utils.py", "w") as f:
            f.write(response.text)

        Path("__init__.py").touch()
    else:
        raise RuntimeError(
            f"Failed to download utils.py. Status code: {response.status_code}"
        )


# If not colab, and also contains subfolderl, add the correct path of util.py
else:
    if subfolder:
        sys.path.append(os.path.dirname(os.getcwd()))

# %%
# Now import and run the setup
from utils import (
    get_yaml_path,
    setup_environment,
)


setup_environment(
    is_colab,
    branch,
    benchmark_data=[
        "adult-income",
    ],
    subfolder=subfolder,
)

# %%
from petsard import Executor

# %% [markdown]
# # YAML Configuration for PETsARD
# PETsARD 的 YAML 設定

# %% [markdown]
# ## Default Synthesis and Default Evaluation
# 預設合成與預設評測

# %%
yaml_file_case: str = "logging-configuration.yaml"

yaml_path_case: str = get_yaml_path(
    is_colab=is_colab,
    yaml_file=yaml_file_case,
    branch=branch,
    subfolder=subfolder,
)
# Out:
# Configuration content:
# ---
# Executor:
#   log_output_type: both
#   log_level: DEBUG
#   log_dir: demo_logs
#   log_filename: PETsARD_demo_{timestamp}.log
# Loader:
#   log-data:
#     filepath: 'benchmark/adult-income.csv'
# Splitter:
#   demo:
#     num_samples: 1
#     train_split_ratio: 0.8
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Evaluator:
#   demo-diagnostic:
#     method: 'sdmetrics-diagnosticreport'
#   demo-quality:
#     method: 'sdmetrics-qualityreport'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Synthesizer'
#   save_report_global:
#     method: 'save_report'
#     granularity: 'global'
# ...

# %% [markdown]
# ### Execution and Result
# 執行與結果

# %%
exec_case = Executor(config=yaml_path_case)
exec_case.run()
# Out:
# 2025-06-23 15:19:59,685 - PETsARD.Executor      - _get_config       - INFO     - Logger reconfigured with settings from YAML
# 2025-06-23 15:19:59,686 - PETsARD.Loader        - __init__          - INFO     - Initializing Loader
# 2025-06-23 15:19:59,686 - PETsARD.Loader        - __init__          - DEBUG    - Loader parameters - filepath: benchmark/adult-income.csv, method: None, column_types: None
# 2025-06-23 15:19:59,687 - PETsARD.LoaderConfig  - __post_init__     - DEBUG    - Initializing LoaderConfig
# 2025-06-23 15:19:59,687 - PETsARD.LoaderConfig  - __post_init__     - DEBUG    - File path information - dir: benchmark, name: adult-income, ext: .csv, ext code: 1
# 2025-06-23 15:19:59,687 - PETsARD.Loader        - __init__          - DEBUG    - LoaderConfig successfully initialized
# 2025-06-23 15:19:59,687 - PETsARD.Synthesizer   - __init__          - INFO     - Initializing Synthesizer with method: default, sample_num_rows: None
# 2025-06-23 15:19:59,688 - PETsARD.SynthesizerConfig - __post_init__     - DEBUG    - Initializing SynthesizerConfig
# 2025-06-23 15:19:59,688 - PETsARD.SynthesizerConfig - __post_init__     - DEBUG    - Mapped synthesizing method 'default' to code 1
# 2025-06-23 15:19:59,688 - PETsARD.SynthesizerConfig - __post_init__     - INFO     - SynthesizerConfig initialized with method: default, syn_method: sdv-single_table-gaussiancopula
# 2025-06-23 15:19:59,688 - PETsARD.Synthesizer   - __init__          - DEBUG    - SynthesizerConfig successfully initialized
# 2025-06-23 15:19:59,689 - PETsARD.Synthesizer   - __init__          - DEBUG    - No additional parameters provided
# 2025-06-23 15:19:59,689 - PETsARD.Synthesizer   - __init__          - INFO     - Synthesizer initialization completed
# 2025-06-23 15:19:59,689 - PETsARD.Evaluator     - __init__          - INFO     - Initializing Evaluator with method: sdmetrics-diagnosticreport
# 2025-06-23 15:19:59,689 - PETsARD.EvaluatorConfig - __post_init__     - DEBUG    - Initializing EvaluatorConfig
# 2025-06-23 15:19:59,689 - PETsARD.EvaluatorConfig - _init_eval_method - DEBUG    - Mapped evaluating method 'sdmetrics-diagnosticreport' to code EvaluatorMap.SDMETRICS
# 2025-06-23 15:19:59,690 - PETsARD.EvaluatorConfig - _init_eval_method - INFO     - EvaluatorConfig initialized with method: sdmetrics-diagnosticreport, eval_method: sdmetrics-diagnosticreport
# 2025-06-23 15:19:59,690 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - EvaluatorConfig successfully initialized
# 2025-06-23 15:19:59,690 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - No additional parameters provided
# 2025-06-23 15:19:59,691 - PETsARD.Evaluator     - __init__          - INFO     - ≈ initialization completed
# 2025-06-23 15:19:59,691 - PETsARD.Evaluator     - __init__          - INFO     - Initializing Evaluator with method: sdmetrics-qualityreport
# 2025-06-23 15:19:59,692 - PETsARD.EvaluatorConfig - __post_init__     - DEBUG    - Initializing EvaluatorConfig
# 2025-06-23 15:19:59,692 - PETsARD.EvaluatorConfig - _init_eval_method - DEBUG    - Mapped evaluating method 'sdmetrics-qualityreport' to code EvaluatorMap.SDMETRICS
# 2025-06-23 15:19:59,692 - PETsARD.EvaluatorConfig - _init_eval_method - INFO     - EvaluatorConfig initialized with method: sdmetrics-qualityreport, eval_method: sdmetrics-qualityreport
# 2025-06-23 15:19:59,692 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - EvaluatorConfig successfully initialized
# 2025-06-23 15:19:59,692 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - No additional parameters provided
# 2025-06-23 15:19:59,693 - PETsARD.Evaluator     - __init__          - INFO     - ≈ initialization completed
# 2025-06-23 15:19:59,693 - PETsARD.Executor      - run               - INFO     - Starting PETsARD execution workflow
# 2025-06-23 15:19:59,693 - PETsARD.Executor      - run               - INFO     - Executing Loader with log-data
# 2025-06-23 15:19:59,694 - PETsARD.LoaderOp      - run               - INFO     - Starting LoaderOp execution
# 2025-06-23 15:19:59,694 - PETsARD.LoaderOp      - _run              - DEBUG    - Starting data loading process
# 2025-06-23 15:19:59,694 - PETsARD.Loader        - load              - INFO     - Loading data from benchmark/adult-income.csv
# 2025-06-23 15:19:59,694 - PETsARD.Loader        - load              - INFO     - Loading data using file extension: .csv
# 2025-06-23 15:19:59,694 - PETsARD.Loader        - load              - DEBUG    - Using inferred headers
# 2025-06-23 15:19:59,743 - PETsARD.Loader        - load              - INFO     - Successfully loaded data with shape: (48842, 15)
# 2025-06-23 15:19:59,744 - PETsARD.Loader        - load              - INFO     - Building schema configuration
# 2025-06-23 15:19:59,744 - PETsARD.Loader        - load              - INFO     - Building schema metadata from dataframe
# 2025-06-23 15:19:59,796 - PETsARD.Loader        - load              - DEBUG    - Built schema with 15 fields
# 2025-06-23 15:19:59,796 - PETsARD.Loader        - load              - INFO     - Applying schema transformations to optimize data
# 2025-06-23 15:19:59,811 - PETsARD.Loader        - load              - DEBUG    - Schema transformations applied successfully
# 2025-06-23 15:19:59,812 - PETsARD.Loader        - load              - INFO     - Data loading completed successfully
# 2025-06-23 15:19:59,812 - PETsARD.LoaderOp      - _run              - DEBUG    - Using SchemaMetadata from Metadater
# 2025-06-23 15:19:59,812 - PETsARD.LoaderOp      - _run              - DEBUG    - Data loading completed
# 2025-06-23 15:19:59,812 - PETsARD.LoaderOp      - run               - INFO     - Completed LoaderOp execution (elapsed: 0:00:00)
# 2025-06-23 15:19:59,813 - PETsARD.Executor      - run               - INFO     - Executing Splitter with demo_[1-1]
# 2025-06-23 15:19:59,813 - PETsARD.SplitterOp    - run               - INFO     - Starting SplitterOp execution
# 2025-06-23 15:19:59,813 - PETsARD.SplitterOp    - _run              - DEBUG    - Starting data splitting process
# 2025-06-23 15:19:59,829 - PETsARD.SplitterOp    - _run              - DEBUG    - Data splitting completed
# 2025-06-23 15:19:59,829 - PETsARD.SplitterOp    - run               - INFO     - Completed SplitterOp execution (elapsed: 0:00:00)
# 2025-06-23 15:19:59,830 - PETsARD.Executor      - run               - INFO     - Executing Preprocessor with demo
# 2025-06-23 15:19:59,830 - PETsARD.PreprocessorOp - run               - INFO     - Starting PreprocessorOp execution
# 2025-06-23 15:19:59,830 - PETsARD.PreprocessorOp - _run              - DEBUG    - Initializing processor
# 2025-06-23 15:19:59,831 - PETsARD.Processor     - __init__          - DEBUG    - Initializing Processor
# 2025-06-23 15:19:59,831 - PETsARD.Processor     - __init__          - DEBUG    - Loaded metadata contains 0 fields
# 2025-06-23 15:19:59,831 - PETsARD.Processor     - __init__          - DEBUG    - config is provided:
# 2025-06-23 15:19:59,831 - PETsARD.Processor     - __init__          - DEBUG    - config is provided: {}
# 2025-06-23 15:19:59,831 - PETsARD.Processor     - __init__          - DEBUG    - Schema metadata loaded.
# 2025-06-23 15:19:59,832 - PETsARD.Processor     - _generate_config  - DEBUG    - Starting config generation
# 2025-06-23 15:19:59,832 - PETsARD.Processor     - _generate_config  - DEBUG    - Config generation completed
# 2025-06-23 15:19:59,832 - PETsARD.Processor     - __init__          - DEBUG    - Config loaded.
# 2025-06-23 15:19:59,832 - PETsARD.PreprocessorOp - _run              - DEBUG    - Using default processing sequence
# 2025-06-23 15:19:59,832 - PETsARD.Processor     - fit               - INFO     - MediatorMissing is created.
# 2025-06-23 15:19:59,832 - PETsARD.Processor     - fit               - INFO     - MediatorOutlier is created.
# 2025-06-23 15:19:59,833 - PETsARD.Processor     - fit               - INFO     - MediatorEncoder is created.
# 2025-06-23 15:19:59,833 - PETsARD.Processor     - fit               - INFO     - MediatorScaler is created.
# 2025-06-23 15:19:59,833 - PETsARD.Processor     - fit               - DEBUG    - Fitting sequence generation completed.
# 2025-06-23 15:19:59,833 - PETsARD.Processor     - fit               - INFO     - missing fitting done.
# 2025-06-23 15:19:59,833 - PETsARD.Processor     - fit               - DEBUG    - mediator: MediatorMissing start processing.
# 2025-06-23 15:19:59,834 - PETsARD.Processor     - fit               - INFO     - MediatorMissing fitting done.
# 2025-06-23 15:19:59,834 - PETsARD.Processor     - fit               - INFO     - outlier fitting done.
# 2025-06-23 15:19:59,834 - PETsARD.Processor     - fit               - DEBUG    - mediator: MediatorOutlier start processing.
# 2025-06-23 15:19:59,834 - PETsARD.Processor     - fit               - INFO     - MediatorOutlier fitting done.
# 2025-06-23 15:19:59,834 - PETsARD.Processor     - fit               - INFO     - encoder fitting done.
# 2025-06-23 15:19:59,834 - PETsARD.Processor     - fit               - DEBUG    - mediator: MediatorEncoder start processing.
# 2025-06-23 15:19:59,835 - PETsARD.Processor     - fit               - INFO     - MediatorEncoder fitting done.
# 2025-06-23 15:19:59,835 - PETsARD.Processor     - fit               - INFO     - scaler fitting done.
# 2025-06-23 15:19:59,835 - PETsARD.PreprocessorOp - _run              - DEBUG    - Transforming data
# 2025-06-23 15:19:59,835 - PETsARD.Processor     - transform         - DEBUG    - Starting data transformation, input shape: (39073, 15)
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - DEBUG    - Executing missing processing
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - INFO     - missing transformation done.
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorMissing start transforming.
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - INFO     - MediatorMissing transformation done.
# 2025-06-23 15:19:59,836 - PETsARD.Processor     - transform         - DEBUG    - Executing outlier processing
# 2025-06-23 15:19:59,837 - PETsARD.Processor     - transform         - INFO     - outlier transformation done.
# 2025-06-23 15:19:59,837 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorOutlier start transforming.
# 2025-06-23 15:19:59,837 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,837 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,837 - PETsARD.Processor     - transform         - INFO     - MediatorOutlier transformation done.
# 2025-06-23 15:19:59,838 - PETsARD.Processor     - transform         - DEBUG    - Executing encoder processing
# 2025-06-23 15:19:59,838 - PETsARD.Processor     - transform         - INFO     - encoder transformation done.
# 2025-06-23 15:19:59,838 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorEncoder start transforming.
# 2025-06-23 15:19:59,838 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,838 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Starting metadata adjustment, mode: global
# 2025-06-23 15:19:59,838 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Performing global metadata adjustment
# 2025-06-23 15:19:59,866 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Created new schema metadata for transformed data with 15 fields
# 2025-06-23 15:19:59,866 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,867 - PETsARD.Processor     - transform         - INFO     - MediatorEncoder transformation done.
# 2025-06-23 15:19:59,867 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorScaler start transforming.
# 2025-06-23 15:19:59,867 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,867 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Starting metadata adjustment, mode: global
# 2025-06-23 15:19:59,868 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Performing global metadata adjustment
# 2025-06-23 15:19:59,887 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Created new schema metadata for transformed data with 15 fields
# 2025-06-23 15:19:59,887 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-23 15:19:59,888 - PETsARD.Processor     - transform         - INFO     - MediatorScaler transformation done.
# 2025-06-23 15:19:59,888 - PETsARD.Processor     - transform         - DEBUG    - Executing scaler processing
# 2025-06-23 15:19:59,892 - PETsARD.Processor     - transform         - INFO     - scaler transformation done.
# 2025-06-23 15:19:59,893 - PETsARD.PreprocessorOp - run               - INFO     - Completed PreprocessorOp execution (elapsed: 0:00:00)
# 2025-06-23 15:19:59,893 - PETsARD.Executor      - run               - INFO     - Executing Synthesizer with demo
# 2025-06-23 15:19:59,893 - PETsARD.SynthesizerOp - set_input         - WARNING  - Metadata from Preprocessor has no fields, setting to None
# 2025-06-23 15:19:59,894 - PETsARD.SynthesizerOp - run               - INFO     - Starting SynthesizerOp execution
# 2025-06-23 15:19:59,894 - PETsARD.SynthesizerOp - _run              - DEBUG    - Starting data synthesizing process
# 2025-06-23 15:19:59,894 - PETsARD.Synthesizer   - create            - INFO     - Creating synthesizer instance
# 2025-06-23 15:19:59,894 - PETsARD.Synthesizer   - create            - DEBUG    - No metadata provided for synthesizer creation
# 2025-06-23 15:19:59,895 - PETsARD.Synthesizer   - _determine_sample_configuration - DEBUG    - Determining sample configuration
# 2025-06-23 15:19:59,895 - PETsARD.Synthesizer   - _determine_sample_configuration - DEBUG    - Using manually specified sample size: 0
# 2025-06-23 15:19:59,895 - PETsARD.Synthesizer   - _determine_sample_configuration - DEBUG    - Using source data as sample source (will be determined during fit)
# 2025-06-23 15:19:59,895 - PETsARD.Synthesizer   - _determine_sample_configuration - INFO     - Sample configuration determined: source=Source data, rows=0
# 2025-06-23 15:19:59,896 - PETsARD.Synthesizer   - create            - DEBUG    - Sample configuration: source=Source data, rows=0
# 2025-06-23 15:19:59,896 - PETsARD.Synthesizer   - create            - DEBUG    - Using synthesizer class: SDVSingleTableSynthesizer
# 2025-06-23 15:19:59,896 - PETsARD.Synthesizer   - create            - DEBUG    - Merged config keys: ['syn_method', 'sample_num_rows']
# 2025-06-23 15:19:59,896 - PETsARD.Synthesizer   - create            - INFO     - Creating SDVSingleTableSynthesizer instance
# 2025-06-23 15:19:59,896 - PETsARD.SDVSingleTableSynthesizer - __init__          - INFO     - Initializing SDVSingleTableSynthesizer with config: {'syn_method': 'sdv-single_table-gaussiancopula', 'sample_num_rows': 0}
# 2025-06-23 15:19:59,896 - PETsARD.SDVSingleTableSynthesizer - __init__          - DEBUG    - No metadata provided, synthesizer will be initialized during fit
# 2025-06-23 15:19:59,897 - PETsARD.Synthesizer   - create            - INFO     - Successfully created SDVSingleTableSynthesizer instance
# 2025-06-23 15:19:59,897 - PETsARD.SynthesizerOp - _run              - DEBUG    - Synthesizing model initialization completed
# 2025-06-23 15:19:59,897 - PETsARD.Synthesizer   - fit               - INFO     - Fitting synthesizer with data shape: (39073, 15)
# 2025-06-23 15:19:59,897 - PETsARD.Synthesizer   - fit               - DEBUG    - Updated sample_num_rows from 0 to 39073
# 2025-06-23 15:19:59,897 - PETsARD.Synthesizer   - fit               - DEBUG    - Updated synthesizer config with sample_num_rows=39073
# 2025-06-23 15:19:59,898 - PETsARD.Synthesizer   - fit               - INFO     - Starting fit process for sdv-single_table-gaussiancopula
# 2025-06-23 15:19:59,898 - PETsARD.SDVSingleTableSynthesizer - fit               - INFO     - Fitting SDVSingleTableSynthesizer
# 2025-06-23 15:19:59,898 - PETsARD.SDVSingleTableSynthesizer - _fit              - INFO     - Fitting synthesizer with data shape: (39073, 15)
# 2025-06-23 15:19:59,898 - PETsARD.SDVSingleTableSynthesizer - _fit              - DEBUG    - Initializing synthesizer in _fit method
# 2025-06-23 15:19:59,898 - PETsARD.SDVMetadataAdapter - create_sdv_metadata - DEBUG    - Creating SDV metadata
# 2025-06-23 15:19:59,899 - PETsARD.SDVMetadataAdapter - create_sdv_metadata - INFO     - Detecting metadata from dataframe with shape (39073, 15)
# 2025-06-23 15:19:59,916 - PETsARD.SDVMetadataAdapter - create_sdv_metadata - DEBUG    - Successfully detected metadata from dataframe
# 2025-06-23 15:19:59,919 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Initializing synthesizer with method: sdv-single_table-gaussiancopula
# 2025-06-23 15:19:59,919 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Mapped method code: 3
# 2025-06-23 15:19:59,920 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Using synthesizer class: GaussianCopulaSynthesizer
# 2025-06-23 15:19:59,923 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Warning during fit: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# 2025-06-23 15:19:59,923 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Successfully created GaussianCopulaSynthesizer instance
# 2025-06-23 15:19:59,924 - PETsARD.SDVSingleTableSynthesizer - _fit              - INFO     - Synthesizer initialized from data
# 2025-06-23 15:19:59,924 - PETsARD.SDVSingleTableSynthesizer - _fit              - DEBUG    - Fitting synthesizer with data
# 2025-06-23 15:20:03,457 - PETsARD.SDVSingleTableSynthesizer - _fit              - INFO     - Successfully fitted synthesizer with data
# 2025-06-23 15:20:03,457 - PETsARD.SDVSingleTableSynthesizer - fit               - INFO     - Successfully fitting SDVSingleTableSynthesizer
# 2025-06-23 15:20:03,457 - PETsARD.Synthesizer   - fit               - INFO     - Fitting completed successfully in 3.5598 seconds
# 2025-06-23 15:20:03,458 - PETsARD.Synthesizer   - sample            - INFO     - Sampling 39073 rows using sdv-single_table-gaussiancopula
# 2025-06-23 15:20:03,458 - PETsARD.SDVSingleTableSynthesizer - sample            - INFO     - Sampling SDVSingleTableSynthesizer
# 2025-06-23 15:20:03,458 - PETsARD.SDVSingleTableSynthesizer - _sample           - INFO     - Sampling 39073 rows from synthesizer
# 2025-06-23 15:20:03,959 - PETsARD.SDVSingleTableSynthesizer - _sample           - INFO     - Successfully sampled 39073 rows
# 2025-06-23 15:20:03,960 - PETsARD.SDVSingleTableSynthesizer - _sample           - DEBUG    - Generated data shape: (39073, 15)
# 2025-06-23 15:20:03,960 - PETsARD.SDVSingleTableSynthesizer - sample            - INFO     - Successfully sampling SDVSingleTableSynthesizer
# 2025-06-23 15:20:03,960 - PETsARD.Synthesizer   - sample            - INFO     - Successfully sampled 39073 rows in 0.5027 seconds
# 2025-06-23 15:20:03,962 - PETsARD.Synthesizer   - sample            - DEBUG    - Sampled data shape: (39073, 15), dtypes: {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}
# 2025-06-23 15:20:03,963 - PETsARD.SynthesizerOp - _run              - DEBUG    - Train and sampling Synthesizing model completed
# 2025-06-23 15:20:03,963 - PETsARD.SynthesizerOp - run               - INFO     - Completed SynthesizerOp execution (elapsed: 0:00:04)
# 2025-06-23 15:20:03,963 - PETsARD.Executor      - run               - INFO     - Executing Postprocessor with demo
# 2025-06-23 15:20:03,964 - PETsARD.PostprocessorOp - run               - INFO     - Starting PostprocessorOp execution
# 2025-06-23 15:20:03,964 - PETsARD.PostprocessorOp - _run              - DEBUG    - Starting data postprocessing process
# 2025-06-23 15:20:03,964 - PETsARD.PostprocessorOp - _run              - DEBUG    - Processor configuration loading completed
# 2025-06-23 15:20:03,964 - PETsARD.Processor     - inverse_transform - INFO     - MediatorEncoder is created.
# 2025-06-23 15:20:03,965 - PETsARD.Processor     - inverse_transform - INFO     - MediatorScaler is created.
# 2025-06-23 15:20:03,965 - PETsARD.Processor     - inverse_transform - DEBUG    - Inverse sequence generation completed.
# 2025-06-23 15:20:03,965 - PETsARD.Processor     - inverse_transform - DEBUG    - mediator: MediatorScaler start inverse transforming.
# 2025-06-23 15:20:03,966 - PETsARD.Processor     - inverse_transform - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-23 15:20:03,966 - PETsARD.Processor     - inverse_transform - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-23 15:20:03,966 - PETsARD.Processor     - inverse_transform - INFO     - MediatorScaler transformation done.
# 2025-06-23 15:20:03,966 - PETsARD.Processor     - inverse_transform - INFO     - str inverse transformation done.
# 2025-06-23 15:20:03,966 - PETsARD.Processor     - inverse_transform - DEBUG    - mediator: MediatorEncoder start inverse transforming.
# 2025-06-23 15:20:03,967 - PETsARD.Processor     - inverse_transform - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-23 15:20:03,967 - PETsARD.Processor     - inverse_transform - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-23 15:20:03,967 - PETsARD.Processor     - inverse_transform - INFO     - MediatorEncoder transformation done.
# 2025-06-23 15:20:03,967 - PETsARD.Processor     - inverse_transform - INFO     - str inverse transformation done.
# 2025-06-23 15:20:03,967 - PETsARD.Processor     - inverse_transform - INFO     - str inverse transformation done.
# 2025-06-23 15:20:03,967 - PETsARD.PostprocessorOp - _run              - DEBUG    - Data postprocessing completed
# 2025-06-23 15:20:03,968 - PETsARD.PostprocessorOp - run               - INFO     - Completed PostprocessorOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:03,968 - PETsARD.Executor      - run               - INFO     - Executing Evaluator with demo-diagnostic
# 2025-06-23 15:20:03,970 - PETsARD.EvaluatorOp   - run               - INFO     - Starting EvaluatorOp execution
# 2025-06-23 15:20:03,970 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Starting data evaluating process
# 2025-06-23 15:20:03,970 - PETsARD.Evaluator     - create            - INFO     - Creating {self.__class__.__name__} instance
# 2025-06-23 15:20:03,970 - PETsARD.Evaluator     - create            - DEBUG    - Using Evaluator class: SDMetricsSingleTable
# 2025-06-23 15:20:03,971 - PETsARD.Evaluator     - create            - DEBUG    - Merged config keys: ['eval_method']
# 2025-06-23 15:20:03,971 - PETsARD.Evaluator     - create            - INFO     - Creating SDMetricsSingleTable instance
# 2025-06-23 15:20:03,971 - PETsARD.SDMetricsSingleTable - __init__          - DEBUG    - Initializing synthesizer with method: sdmetrics-diagnosticreport
# 2025-06-23 15:20:03,971 - PETsARD.SDMetricsSingleTable - __init__          - DEBUG    - Mapped method code: SDMetricsSingleTableMap.DIAGNOSTICREPORT
# 2025-06-23 15:20:03,973 - PETsARD.Evaluator     - create            - INFO     - Successfully created SDMetricsSingleTable instance
# 2025-06-23 15:20:03,973 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Evaluation model initialization completed
# 2025-06-23 15:20:03,973 - PETsARD.Evaluator     - eval              - INFO     - Evaluating data with keys ['ori', 'syn', 'control'] using evaluation method: sdmetrics-diagnosticreport
# 2025-06-23 15:20:03,973 - PETsARD.EvaluatorInputConfig - __post_init__     - DEBUG    - Initializing EvaluatorInputDataConfig
# 2025-06-23 15:20:03,998 - PETsARD.SDMetricsSingleTable - eval              - DEBUG    - Merged config keys: ['ori', 'syn']
# 2025-06-23 15:20:03,998 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Evaluating SDMetricsSingleTable
# 2025-06-23 15:20:03,999 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Evaluating with data
# 2025-06-23 15:20:03,999 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Initializing SDMetricsSingleTableConfig
# 2025-06-23 15:20:03,999 - PETsARD.SDMetricsSingleTableConfig - create_metadata   - DEBUG    - Creating SDV metadata
# 2025-06-23 15:20:04,015 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Initializing evaluator in _eval method
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 1072.80it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 972.03it/s]|
# Data Structure Score: 100.0%
# 2025-06-23 15:20:04,032 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully evaluating from data
# 2025-06-23 15:20:04,032 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extract scores level from SDMetrics
# 2025-06-23 15:20:04,033 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting properties level from SDMetrics
# 2025-06-23 15:20:04,034 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting details level from SDMetrics
# 2025-06-23 15:20:04,034 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracted scores: ['score', 'properties', 'details']
# 2025-06-23 15:20:04,034 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting global level as PETsARD format
# 2025-06-23 15:20:04,034 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting columnwise level as PETsARD format
# 2025-06-23 15:20:04,035 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting pairwise level as PETsARD format
# 2025-06-23 15:20:04,035 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully extracting scores
# 2025-06-23 15:20:04,035 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Successfully evaluating SDMetricsSingleTable
# 2025-06-23 15:20:04,036 - PETsARD.Evaluator     - eval              - INFO     - Evaluation completed successfully in 0.0629 seconds
# 2025-06-23 15:20:04,038 - PETsARD.Evaluator     - eval              - DEBUG    - Evaluation report summary: Data keys: ['ori', 'syn', 'control'], Column count by type per dataframe: {'ori': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'syn': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'control': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}}, Columns by key: {'ori': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'syn': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'control': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']}
# 2025-06-23 15:20:04,039 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Data evaluating completed
# 2025-06-23 15:20:04,039 - PETsARD.EvaluatorOp   - run               - INFO     - Completed EvaluatorOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:04,039 - PETsARD.Executor      - run               - INFO     - Executing Reporter with output
# 2025-06-23 15:20:04,043 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-06-23 15:20:04,043 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-06-23 15:20:04,043 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removing 'exist_report': All entries were invalid
# 2025-06-23 15:20:04,043 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removed 1 invalid entries from input data
# 2025-06-23 15:20:04,043 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-06-23 15:20:04,122 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-06-23 15:20:04,123 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:04,123 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-06-23 15:20:04,124 - PETsARD.Executor      - run               - INFO     - Executing Reporter with save_report_global
# 2025-06-23 15:20:04,125 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-06-23 15:20:04,125 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-06-23 15:20:04,126 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-06-23 15:20:04,127 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-06-23 15:20:04,127 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:04,127 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-06-23 15:20:04,127 - PETsARD.Executor      - run               - INFO     - Executing Evaluator with demo-quality
# 2025-06-23 15:20:04,129 - PETsARD.EvaluatorOp   - run               - INFO     - Starting EvaluatorOp execution
# 2025-06-23 15:20:04,129 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Starting data evaluating process
# 2025-06-23 15:20:04,129 - PETsARD.Evaluator     - create            - INFO     - Creating {self.__class__.__name__} instance
# 2025-06-23 15:20:04,129 - PETsARD.Evaluator     - create            - DEBUG    - Using Evaluator class: SDMetricsSingleTable
# 2025-06-23 15:20:04,129 - PETsARD.Evaluator     - create            - DEBUG    - Merged config keys: ['eval_method']
# 2025-06-23 15:20:04,129 - PETsARD.Evaluator     - create            - INFO     - Creating SDMetricsSingleTable instance
# 2025-06-23 15:20:04,130 - PETsARD.SDMetricsSingleTable - __init__          - DEBUG    - Initializing synthesizer with method: sdmetrics-qualityreport
# 2025-06-23 15:20:04,130 - PETsARD.SDMetricsSingleTable - __init__          - DEBUG    - Mapped method code: SDMetricsSingleTableMap.QUALITYREPORT
# 2025-06-23 15:20:04,131 - PETsARD.Evaluator     - create            - INFO     - Successfully created SDMetricsSingleTable instance
# 2025-06-23 15:20:04,131 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Evaluation model initialization completed
# 2025-06-23 15:20:04,131 - PETsARD.Evaluator     - eval              - INFO     - Evaluating data with keys ['ori', 'syn', 'control'] using evaluation method: sdmetrics-qualityreport
# 2025-06-23 15:20:04,132 - PETsARD.EvaluatorInputConfig - __post_init__     - DEBUG    - Initializing EvaluatorInputDataConfig
# 2025-06-23 15:20:04,152 - PETsARD.SDMetricsSingleTable - eval              - DEBUG    - Merged config keys: ['ori', 'syn']
# 2025-06-23 15:20:04,152 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Evaluating SDMetricsSingleTable
# 2025-06-23 15:20:04,152 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Evaluating with data
# 2025-06-23 15:20:04,152 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Initializing SDMetricsSingleTableConfig
# 2025-06-23 15:20:04,153 - PETsARD.SDMetricsSingleTableConfig - create_metadata   - DEBUG    - Creating SDV metadata
# 2025-06-23 15:20:04,169 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Initializing evaluator in _eval method
# Overall Score (Average): 100.0%
#
# Now is petsard_Loader[log-data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo] save to csv...
# Now is petsard[Report]_[global] save to csv...
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 134.23it/s]|
# Column Shapes Score: 77.96%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 387.00it/s]|
# Column Pair Trends Score: 69.28%
# 2025-06-23 15:20:04,554 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,555 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,555 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,555 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,555 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,555 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,556 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,556 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,556 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,556 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,556 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,556 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,557 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,557 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,557 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,557 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,557 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...
# 2025-06-23 15:20:04,584 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,584 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,584 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,585 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,585 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Overall Score (Average): 73.62%
# 2025-06-23 15:20:04,585 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,585 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,585 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,586 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,586 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,586 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,586 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-23 15:20:04,586 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully evaluating from data
# 2025-06-23 15:20:04,586 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extract scores level from SDMetrics
# 2025-06-23 15:20:04,587 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting properties level from SDMetrics
# 2025-06-23 15:20:04,587 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting details level from SDMetrics
# 2025-06-23 15:20:04,588 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracted scores: ['score', 'properties', 'details']
# 2025-06-23 15:20:04,588 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting global level as PETsARD format
# 2025-06-23 15:20:04,588 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting columnwise level as PETsARD format
# 2025-06-23 15:20:04,589 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting pairwise level as PETsARD format
# 2025-06-23 15:20:04,589 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully extracting scores
# 2025-06-23 15:20:04,590 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Successfully evaluating SDMetricsSingleTable
# 2025-06-23 15:20:04,590 - PETsARD.Evaluator     - eval              - INFO     - Evaluation completed successfully in 0.4585 seconds
# 2025-06-23 15:20:04,593 - PETsARD.Evaluator     - eval              - DEBUG    - Evaluation report summary: Data keys: ['ori', 'syn', 'control'], Column count by type per dataframe: {'ori': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'syn': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'control': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}}, Columns by key: {'ori': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'syn': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'control': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']}
# 2025-06-23 15:20:04,593 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Data evaluating completed
# 2025-06-23 15:20:04,593 - PETsARD.EvaluatorOp   - run               - INFO     - Completed EvaluatorOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:04,594 - PETsARD.Executor      - run               - INFO     - Executing Reporter with output
# 2025-06-23 15:20:04,601 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-06-23 15:20:04,601 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-06-23 15:20:04,602 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# Now is petsard_Loader[log-data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo] save to csv...
# 2025-06-23 15:20:04,700 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-06-23 15:20:04,701 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:04,701 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-06-23 15:20:04,702 - PETsARD.Executor      - run               - INFO     - Executing Reporter with save_report_global
# 2025-06-23 15:20:04,705 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-06-23 15:20:04,706 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-06-23 15:20:04,708 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-06-23 15:20:04,708 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-06-23 15:20:04,708 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-06-23 15:20:04,709 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-06-23 15:20:04,709 - PETsARD.Executor      - run               - INFO     - Completed PETsARD execution workflow (elapsed: 0:00:05)
# Now is petsard[Report]_[global] save to csv...

# %%
exec_case.get_result()[
    "Loader[log-data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo-quality]_Reporter[save_report_global]"
]["[global]"]
# Out:
#                                       full_expt_name    Loader    Splitter  \
# 0  Loader[log-data]_Splitter[demo_[1-1]]_Preproce...  log-data  demo_[1-1]
#
#   Preprocessor Synthesizer Postprocessor Evaluator  demo-diagnostic_Score  \
# 0         demo        demo          demo  [global]                    1.0
#
#    demo-diagnostic_Data Validity  demo-diagnostic_Data Structure  \
# 0                            NaN                             NaN
#
#    demo-quality_Score  demo-quality_Column Shapes  \
# 0                0.74                         NaN
#
#    demo-quality_Column Pair Trends
# 0                              NaN
